# %% [markdown]
# <a href="https://colab.research.google.com/github/gauridhepe21-glitch/Python_AIML_Lab/blob/main/Special_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5f09d79c-4415-4134-8e7c-3b2c78b99327" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f09d79c-4415-4134-8e7c-3b2c78b99327">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("insurance (1).csv")
print(df.head())
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
print("Shape:", df.shape)
# Out:
# Shape: (1338, 7)

# %%
print(df.describe())
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
sns.histplot(df['age'], kde=True)
plt.title("Distribution of age")
plt.show()

# %%
sns.countplot(x='smoker', data=df)
plt.title("smokerCount")
plt.show()

# %%
print("\nObservations:")
print("1. Dataset has 150 flower samples.")
print("2. No missing values are present.")
print("3. Setosa species has smaller petal length.")
print("4. Sepal and Petal measurements show positive correlation.")
# Out:
# Observations:
# 1. Dataset has 150 flower samples.
# 2. No missing values are present.
# 3. Setosa species has smaller petal length.
# 4. Sepal and Petal measurements show positive correlation.

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.select_dtypes(include='number').corr(),
            annot=True,
            cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
