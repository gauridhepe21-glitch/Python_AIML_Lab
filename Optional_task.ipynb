# %% [markdown]
# <a href="https://colab.research.google.com/github/gauridhepe21-glitch/Python_AIML_Lab/blob/main/Optional_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-3aefb6a6-4c9f-4a3e-96b6-131c2553ca78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3aefb6a6-4c9f-4a3e-96b6-131c2553ca78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("insurance.csv")

# %%
print(df.head())
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
print("Shape :", df.shape)
# Out:
# Shape : (1338, 7)

# %%
print(df.dtypes)
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
print("\nDuplicate Rows :", df.duplicated().sum())
# Out:
# Duplicate Rows : 1

# %%
df = df.drop_duplicates()

# %%
num_cols = ["age", "bmi", "children", "expenses"]

for col in num_cols:
    plt.figure(figsize=(5,4))
    plt.hist(df[col], bins=20)
    plt.title(col)
    plt.show()

# %%
cat_cols = ["sex", "smoker", "region"]

for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col, data=df)
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize=(6,5))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm")
plt.show()

# %%
X = df.drop("expenses", axis=1)
y = df["expenses"]

print("\nInput Features")
print(X.columns)

print("\nOutput Feature")
print(y.name)
# Out:
# Input Features
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region'], dtype='object')
#
# Output Feature
# expenses
